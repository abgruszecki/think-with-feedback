# %%
import pandas as pd
from pathlib import Path

# Determine our base folder:
try:
    # If we're in a script, this points to flow_mutants/
    here = Path(__file__).resolve().parent
except NameError:
    # In a REPL/notebook __file__ doesn't exist—use cwd()
    here = Path.cwd()

# Build the path to the JSONL in the sibling flow_sig_points folder
jsonl_path = (
    here.parent  # up from flow_mutants to the project root
    / "flow_sig_points"
    / "out"
    / "simulation_replacements"
    / "processed-report.jsonl"
)

# Read it
df = pd.read_json(jsonl_path, lines=True)

# display df
df
# Out:
#      idx  offset  candidate_offset  reasoning_len nums  \
# 0    376    9817            8665.0            413  [3]
# 1    202   47236               NaN            656  [1]
# 2    689   34603           30830.0           1617  [1]
# 3    710   21643           19801.0            382  [1]
# 4     73    6889            5240.0            130  [1]
# ..   ...     ...               ...            ...  ...
# 241  678   41933           40983.0             83  [1]
# 242  367   54219               NaN           1141  [1]
# 243   93   20573           17407.0           1986  [2]
# 244  685   24864               NaN           1352  [1]
# 245  803   70477               NaN            535  [1]
#
#                                                   code             status  \
# 0    def main(input_stream, output_stream):\n    f ...            success
# 1    def main(input_stream, output_stream):\n    n,...            success
# 2    import sys\nfrom collections import defaultdic...            success
# ...
